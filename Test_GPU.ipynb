# %%
! export PYTORCH_CUDA_ALLOC_CONF="expandable_segments:True"

# %%
    import torch
    print(torch.cuda.is_available())
    # If available, print the number of GPUs
    if torch.cuda.is_available():
        print(f"Number of GPUs: {torch.cuda.device_count()}")
        # Print the name of the current GPU (should show H100)
        print(f"Current GPU name: {torch.cuda.get_device_name(0)}")
# Out:
# True
# Number of GPUs: 1
# Current GPU name: NVIDIA H100 NVL

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

if device.type == 'cuda':
    # Allocate some memory on the GPU
    x = torch.randn(1000, 1000).to(device)

    # Get the allocated memory in bytes
    allocated_bytes = torch.cuda.memory_allocated(device)
    print(f"Allocated memory: {allocated_bytes / (1024**3):.2f} GB")
else:
    print("CUDA is not available, cannot check GPU memory.")
# Out:
# Allocated memory: 0.00 GB

# %%
# !nvidia-smi
# Out:
# Fri Nov 21 03:08:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 NVL                On  |   00000000:1F:00.0 Off |                    0 |
# | N/A   70C    P0            398W /  400W |   89989MiB /  95830MiB |    100%      Default |
# |                                         |                        |             Disabled |
# ...
