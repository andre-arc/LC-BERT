# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("dataset/ag-news/train.csv")
valid_data = pd.read_csv("dataset/ag-news/valid.csv")
test_data = pd.read_csv("dataset/ag-news/test.csv")

# %%
train_data['Class Index'].value_counts()
# Out:
# 3    24089
# 1    24044
# 2    23942
# 4    23925
# Name: Class Index, dtype: int64

# %%
valid_data['Class Index'].value_counts()
# Out:
# 4    6075
# 2    6058
# 1    5956
# 3    5911
# Name: Class Index, dtype: int64

# %%
test_data['Class Index'].value_counts()
# Out:
# 3    1900
# 4    1900
# 2    1900
# 1    1900
# Name: Class Index, dtype: int64
