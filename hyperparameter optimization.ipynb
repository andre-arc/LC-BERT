# %% [markdown]
# # FInd Optimal Hyperparameters using Grid Search CV

# %% [markdown]
# #

# %%
import os
import shutil
from copy import deepcopy
import random
import numpy as np
import pandas as pd
import torch
from torch import optim
from torch.optim.lr_scheduler import StepLR
from tqdm import tqdm
from transformers import AdamW

from utils.functions import load_model, load_extraction_model
from utils.args_helper import get_parser, append_dataset_args
from torch.utils.data import DataLoader
from data_utils.ag_news.whitening import BertWhiteningDataset, BertWhiteningDataLoader
from utils.forward_fn import forward_word_classification, modified_forward_word_classification
from utils.metrics import news_categorization_metrics_fn
import time
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Andri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Andri\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Andri\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# !pip install skorch
# Out:
# Requirement already satisfied: skorch in c:\python310\lib\site-packages (0.15.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\python310\lib\site-packages (from skorch) (1.0.2)
# Requirement already satisfied: tqdm>=4.14.0 in c:\python310\lib\site-packages (from skorch) (4.64.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\python310\lib\site-packages (from skorch) (1.8.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\python310\lib\site-packages (from skorch) (0.8.10)
# Requirement already satisfied: numpy>=1.13.3 in c:\python310\lib\site-packages (from skorch) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\andri\appdata\roaming\python\python310\site-packages (from scikit-learn>=0.22.0->skorch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn>=0.22.0->skorch) (3.1.0)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm>=4.14.0->skorch) (0.4.4)
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
args = {
        'device': 0,
        'seed': 88,
        'lr': 2e-3,
        'eps': 1e-8,
        'max_seq_len': 512,
        'num_labels': 4,
        'model_name': 'bilstm-dim-reduction',
        'task': 'sequence_classification',
        'num_labels': BertWhiteningDataset.NUM_LABELS,
        'dataset_class': BertWhiteningDataset,
        'dataloader_class': BertWhiteningDataLoader,
        'extract_model': 'bert-base-uncased',
        'forward_fn': modified_forward_word_classification,
        'metrics_fn': news_categorization_metrics_fn,
        'valid_criterion': 'F1',
        'train_set_path': './dataset/ag-news/train.csv',
        'valid_set_path': './dataset/ag-news/valid.csv',
        'test_set_path': './dataset/ag-news/test.csv',
        'vocab_path': "",
        'train_batch_size': 128,
        'valid_batch_size': 4,
        'vocab_path': "",
        'lower': True,
        'no_special_token': True,
        'k_fold': 1
    }

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

# %%
def efficiency_metrics_wrapper(function):
    def wrapper(*args, **kwargs):

        start_time = time.time()  # Record the start time
        result = function(*args, **kwargs)
        elapsed_time = time.time() - start_time  # Calculate the elapsed time
        gpu_used = torch.cuda.max_memory_allocated() / (1024 * 1024) # in MB

        return result, elapsed_time, gpu_used
    
    return wrapper

# %%
from torch.utils.data import ConcatDataset

extract_model, extract_tokenizer, a, b_ = load_extraction_model(args)
train_dataset_path = args['train_set_path']
train_dataset = args['dataset_class'](args['device'], train_dataset_path, extract_tokenizer, extract_model, args['max_seq_len'],  lowercase=args["lower"], no_special_token=args['no_special_token'])


valid_dataset_path = args['valid_set_path']
valid_dataset = args['dataset_class'](args['device'], valid_dataset_path, extract_tokenizer, extract_model, args['max_seq_len'], lowercase=args["lower"], no_special_token=args['no_special_token'])


test_dataset_path = args['test_set_path']
test_dataset = args['dataset_class'](args['device'], test_dataset_path, extract_tokenizer, extract_model, args['max_seq_len'], lowercase=args["lower"], no_special_token=args['no_special_token'])
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Word Embedding Process: 7600 / 7600 words | GPU Usages: 839.4 3

# %%
# Merge datasets
merged_dataset = ConcatDataset([train_dataset, valid_dataset, test_dataset])

# Create a DataLoader for the merged dataset
merged_loader = args['dataloader_class'](dataset=merged_dataset, batch_size=args['train_batch_size'], shuffle=True)

# %%
import torch
from torch import nn
from torch.nn import CrossEntropyLoss, MSELoss
import torch.nn.functional as F

class BiLSTMLayer(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=1):
        super(BiLSTMLayer, self).__init__()

        self.lstm = nn.LSTM(input_size=input_size, 
                            hidden_size=hidden_size, 
                            num_layers=num_layers, 
                            batch_first=True, 
                            bidirectional=True)
    
    def forward(self, input):
        outputs, _ = self.lstm(input)
        return outputs[:, -1, :]

class BiLSTMForWordClassification(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size):
        super(BiLSTMForWordClassification, self).__init__()

        self.classifier = nn.Sequential(
            nn.Dropout(0.1),
            BiLSTMLayer(input_size=input_size, hidden_size=hidden_size, num_layers=2),
            nn.Linear(hidden_size*2, num_classes),
            nn.ReLU()
        )

        # self.classifier = nn.Sequential(
        #     nn.Dropout(0.1),
        #     BiLSTMLayer(input_size=input_size, hidden_size=hidden_size, num_layers=2),
        #     nn.Linear(hidden_size*2, num_classes),
        #     nn.ReLU(),
        #     # nn.Dropout(0.1),
        #     nn.Softmax(dim=1)
        # )
        # self.classifier = nn.Linear(input_size, num_classes)
        # self.dropout = nn.Dropout()

        self.num_classes = num_classes

    def forward(self, vector):
        logits = self.classifier(vector)
        outputs = F.softmax(logits, dim=1)
        
        return outputs

# %%
model = BiLSTMForWordClassification(args['num_labels'], input_size=256, hidden_size=32)

# %%
# !pip install optuna

# %%
 # Make sure cuda is deterministic
torch.backends.cudnn.deterministic = True

 # Set random seed
set_seed(args['seed'])  # Added here for reproductibility    

w2i, i2w = args['dataset_class'].LABEL2INDEX, args['dataset_class'].INDEX2LABEL
metrics_scores = []
result_dfs = []
efficiency_metrics = []

print(model)
# Out:
# BiLSTMForWordClassification(
#   (classifier): Sequential(
#     (0): Dropout(p=0.1, inplace=False)
#     (1): BiLSTMLayer(
#       (lstm): LSTM(256, 32, num_layers=2, batch_first=True, bidirectional=True)
#     )
#     (2): Linear(in_features=64, out_features=4, bias=True)
#     (3): ReLU()
#   )
# )

# %%
# Learning parameters. 
lr = 0.001
epochs = 20
device = 'cpu'
print(f"Computation device: {device}\n")

# Loss function. Required for defining `NeuralNetClassifier`
criterion = CrossEntropyLoss()

# Define hyperparameters to search
params = {
    'lr': [2e-3, 2e-4, 5e-3, 5e-4],
    'max_epochs': list(range(1, 10, 1)),
    'module__hidden_size': [32, 64, 128],
    'optimizer__eps': [1e-7, 1e-6, 1e-8],  # Add epsilon values for numerical stability
    'optimizer': [torch.optim.Adam, torch.optim.AdamW, torch.optim.Adamax],
    
}
# Out:
# Computation device: cpu

# %%
# from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
# from ignite.handlers import ModelCheckpoint
# from ignite.contrib.handlers import GridSearch

# # Define the training function
# def train_fn(engine, batch):
#     model.train()
#     optimizer.zero_grad()
#     x, y = batch
#     y_pred = model(x)
#     loss = criterion(y_pred, y)
#     loss.backward()
#     optimizer.step()
#     return loss.item()

# # Set up the trainer and evaluator
# trainer = create_supervised_trainer(model, optimizer, criterion, device='cuda' if torch.cuda.is_available() else 'cpu')
# evaluator = create_supervised_evaluator(model, metrics={'accuracy': ignite.metrics.Accuracy()}, device='cuda' if torch.cuda.is_available() else 'cpu')

# # Set up the parameter grid search
# gs = GridSearch(trainer, params, evaluator, score_name="accuracy", smaller_is_better=False)

# # Attach the grid search to the trainer
# gs.attach(trainer)

# # Run the training loop
# trainer.run(dataloader, max_epochs=10)

from skorch import NeuralNetClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Create skorch NeuralNetClassifier
net = NeuralNetClassifier(
    BiLSTMForWordClassification,
    module__input_size=256,  # Assuming input size is the number of features
    module__num_classes=4,  # Adjust based on the number of classes in your task
    module__hidden_size=32,
    max_epochs=10,
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.Adam,
    iterator_train__shuffle=True,
    device=device
)

# %%
"""
Define `GridSearchCV`.
4 lrs * 7 max_epochs * 4 module__first_conv_out * 3 module__first_fc_out
* 2 CVs = 672 fits.
"""
gs = GridSearchCV(
    net, params, refit=False, scoring='accuracy', verbose=1, cv=2
)
counter = 0
# Run each fit for 2 batches. So, if we have `n` fits, then it will
# actually for `n*2` times. We have 672 fits, so total, 
# 672 * 2 = 1344 runs.
search_batches = 2
"""
This will run `n` (`n` is calculated from `params`) number of fits 
on each batch of data, so be careful.
If you want to run the `n` number of fits just once, 
that is, on one batch of data,
add `break` after this line:
    `outputs = gs.fit(image, labels)`
Note: This will take a lot of time to run
"""
for i, data in enumerate(merged_loader):
    counter += 1
    vector_batch, label_batch = data[:-1]
    # Prepare input & label
    vector_batch = torch.FloatTensor(vector_batch)
    label_batch = torch.LongTensor(label_batch)

    if device == "cuda":
        vector_batch = vector_batch.cuda()
        label_batch = label_batch.cuda()
    
    outputs = gs.fit(vector_batch, label_batch)

    # GridSearch for `search_batches` number of times.
    if counter == search_batches:
        break

print('SEARCH COMPLETE')
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_))

# Print the best parameters and accuracy
# print("Best Parameters:", best_params)
# print("Test Accuracy:", accuracy)
# Out:
# Fitting 2 folds for each of 972 candidates, totalling 1944 fits
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3872       0.2308        1.3868  0.0521
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3872       0.2308        1.3868  0.0050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3873       0.2308        1.3868  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3872       0.2308        1.3867  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3858  0.0066
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.2308        1.3858  0.0050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3847       0.3077        1.3847  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3851       0.3077        1.3843  0.0064
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.2308        1.3867  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3837       0.3077        1.3821  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.2308        1.3858  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.1538        1.3871  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3871  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.3077        1.3857  0.0061
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3865  0.0050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3850       0.3077        1.3850  0.0050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.1538        1.3855  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3855       0.3077        1.3852  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3863  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3862  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3873       0.2308        1.3865  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3855       0.3077        1.3850  0.0078
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3862  0.0068
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3863  0.0071
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3866  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.1538        1.3874  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3864  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3849  0.0104
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3860  0.0100
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.3077        1.3849  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3862  0.0103
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.3077        1.3854  0.0098
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3864  0.0100
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.3846        1.3863  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3870       0.2308        1.3863  0.0065
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.3077        1.3850  0.0097
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3851  0.0160
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3854  0.0130
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3851       0.3077        1.3846  0.0125
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.3077        1.3853  0.0100
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3862  0.0113
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.3077        1.3857  0.0105
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3874       0.2308        1.3864  0.0125
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3858       0.3077        1.3848  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.4615        1.3855  0.0140
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3854  0.0160
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.2308        1.3853  0.0151
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.3077        1.3844  0.0140
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3860  0.0143
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3855       0.3077        1.3844  0.0125
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3864  0.0140
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3857  0.0150
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.2308        1.3856  0.0144
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3848  0.0145
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.2308        1.3853  0.0040
#       2        1.3853       0.3077        1.3850  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.3077        1.3853  0.0060
#       2        1.3851       0.3077        1.3850  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3862  0.0050
#       2        1.3861       0.2308        1.3861  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3849       0.3077        1.3846  0.0100
#       2        1.3844       0.3077        1.3843  0.0074
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3873       0.2308        1.3867  0.0070
#       2        1.3869       0.2308        1.3865  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.3077        1.3860  0.0070
#       2        1.3857       0.3077        1.3855  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3861  0.0050
#       2        1.3861       0.2308        1.3857  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3842       0.3077        1.3838  0.0060
#       2        1.3838       0.3077        1.3835  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0063
#       2        1.3863       0.2308        1.3863  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0062
#       2        1.3863       0.2308        1.3863  0.0061
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0053
#       2        1.3863       0.2308        1.3863  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.3077        1.3848  0.0060
#       2        1.3860       0.3077        1.3846  0.0062
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3850       0.3077        1.3847  0.0060
#       2        1.3846       0.3077        1.3845  0.0075
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3851       0.3077        1.3849  0.0060
#       2        1.3847       0.3077        1.3847  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.1538        1.3862  0.0060
#       2        1.3861       0.3077        1.3860  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3871  0.0074
#       2        1.3855       0.3077        1.3866  0.0063
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3848       0.4615        1.3849  0.0050
#       2        1.3843       0.3077        1.3846  0.0075
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3874       0.2308        1.3874  0.0066
#       2        1.3869       0.2308        1.3871  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3863  0.0070
#       2        1.3863       0.2308        1.3863  0.0101
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0080
#       2        1.3863       0.2308        1.3863  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3858  0.0080
#       2        1.3855       0.5385        1.3853  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3864  0.0085
#       2        1.3856       0.3077        1.3856  0.0101
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3870       0.2308        1.3866  0.0080
#       2        1.3866       0.2308        1.3863  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3848  0.0070
#       2        1.3855       0.6154        1.3842  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3873       0.2308        1.3866  0.0080
#       2        1.3863       0.2308        1.3860  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.1538        1.3873  0.0080
#       2        1.3864       0.1538        1.3868  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3863  0.0080
#       2        1.3863       0.2308        1.3862  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.3077        1.3859  0.0080
#       2        1.3855       0.3077        1.3853  0.0087
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3871       0.2308        1.3869  0.0070
#       2        1.3865       0.2308        1.3865  0.0166
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3859  0.0131
#       2        1.3847       0.3077        1.3852  0.0110
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0140
#       2        1.3863       0.2308        1.3863  0.0124
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3859  0.0120
#       2        1.3860       0.3077        1.3856  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3850  0.0151
#       2        1.3846       0.3077        1.3844  0.0134
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3858       0.3077        1.3843  0.0110
#       2        1.3852       0.3077        1.3838  0.0150
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.2308        1.3856  0.0101
#       2        1.3848       0.4615        1.3851  0.0090
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.1538        1.3868  0.0155
#       2        1.3855       0.3077        1.3862  0.0089
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.2308        1.3862  0.0104
#       2        1.3858       0.2308        1.3856  0.0109
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3841  0.0140
#       2        1.3843       0.3077        1.3832  0.0132
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.2308        1.3863  0.0100
#       2        1.3863       0.4615        1.3861  0.0130
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.3077        1.3857  0.0120
#       2        1.3860       0.3077        1.3853  0.0118
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3862  0.0120
#       2        1.3860       0.2308        1.3863  0.0130
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0120
#       2        1.3863       0.2308        1.3863  0.0140
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3861  0.0130
#       2        1.3858       0.2308        1.3857  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3863  0.0120
#       2        1.3863       0.2308        1.3863  0.0125
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.2308        1.3862  0.0128
#       2        1.3862       0.2308        1.3863  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.2308        1.3863  0.0120
#       2        1.3862       0.2308        1.3861  0.0100
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.5385        1.3852  0.0141
#       2        1.3848       0.3077        1.3842  0.0123
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3862  0.0120
#       2        1.3858       0.2308        1.3863  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3861  0.0130
#       2        1.3858       0.2308        1.3857  0.0145
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.1538        1.3870  0.0135
#       2        1.3863       0.1538        1.3864  0.0150
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3861  0.0130
#       2        1.3860       0.2308        1.3858  0.0150
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.3077        1.3862  0.0150
#       2        1.3853       0.3077        1.3852  0.0170
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0140
#       2        1.3857       0.2308        1.3859  0.0150
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.3077        1.3856  0.0135
#       2        1.3853       0.3077        1.3851  0.0140
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.3077        1.3858  0.0050
#       2        1.3854       0.3077        1.3855  0.0062
#       3        1.3849       0.3077        1.3851  0.0049
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.4615        1.3846  0.0064
#       2        1.3859       0.3846        1.3841  0.0062
#       3        1.3853       0.3077        1.3836  0.0064
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3879       0.2308        1.3871  0.0063
#       2        1.3876       0.2308        1.3869  0.0054
#       3        1.3872       0.2308        1.3867  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3851       0.3077        1.3857  0.0050
#       2        1.3847       0.3077        1.3852  0.0089
#       3        1.3843       0.3077        1.3848  0.0052
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3847       0.3077        1.3844  0.0050
#       2        1.3842       0.3077        1.3843  0.0088
#       3        1.3839       0.3077        1.3840  0.0064
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.1538        1.3874  0.0060
#       2        1.3857       0.3077        1.3870  0.0061
#       3        1.3853       0.3077        1.3866  0.0054
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3865  0.0100
#       2        1.3860       0.2308        1.3864  0.0076
#       3        1.3857       0.2308        1.3862  0.0075
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3845       0.3077        1.3847  0.0065
#       2        1.3841       0.3077        1.3845  0.0088
#       3        1.3838       0.3077        1.3843  0.0063
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3877       0.2308        1.3872  0.0068
#       2        1.3873       0.2308        1.3870  0.0083
#       3        1.3869       0.2308        1.3867  0.0079
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.3077        1.3840  0.0050
#       2        1.3851       0.3077        1.3837  0.0070
#       3        1.3846       0.3077        1.3834  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3869  0.0054
#       2        1.3863       0.2308        1.3866  0.0080
#       3        1.3858       0.2308        1.3863  0.0056
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.3077        1.3842  0.0078
#       2        1.3863       0.3077        1.3838  0.0073
#       3        1.3857       0.3077        1.3835  0.0067
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3857       0.3077        1.3854  0.0050
#       2        1.3852       0.3077        1.3851  0.0060
#       3        1.3848       0.3077        1.3849  0.0057
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3845       0.3077        1.3838  0.0055
#       2        1.3840       0.3077        1.3835  0.0060
#       3        1.3836       0.3077        1.3831  0.0059
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3853       0.3077        1.3851  0.0050
#       2        1.3848       0.3077        1.3848  0.0074
#       3        1.3843       0.3077        1.3845  0.0052
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.2308        1.3863  0.0057
#       2        1.3864       0.2308        1.3860  0.0078
#       3        1.3862       0.3077        1.3858  0.0055
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.3077        1.3854  0.0066
#       2        1.3854       0.3077        1.3851  0.0055
#       3        1.3849       0.3077        1.3848  0.0069
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3875       0.1538        1.3892  0.0075
#       2        1.3873       0.1538        1.3889  0.0066
#       3        1.3871       0.1538        1.3886  0.0067
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0086
#       2        1.3863       0.2308        1.3861  0.0073
#       3        1.3860       0.2308        1.3860  0.0093
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3865  0.0080
#       2        1.3865       0.2308        1.3863  0.0073
#       3        1.3861       0.2308        1.3862  0.0083
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3853       0.3077        1.3855  0.0073
#       2        1.3846       0.3077        1.3849  0.0081
#       3        1.3839       0.3077        1.3845  0.0068
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3858       0.3077        1.3849  0.0069
#       2        1.3850       0.3077        1.3845  0.0079
#       3        1.3843       0.3077        1.3841  0.0082
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3858  0.0083
#       2        1.3854       0.2308        1.3852  0.0099
#       3        1.3845       0.2308        1.3846  0.0071
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0061
#       2        1.3863       0.2308        1.3863  0.0080
#       3        1.3863       0.2308        1.3863  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.2308        1.3863  0.0074
#       2        1.3859       0.2308        1.3862  0.0097
#       3        1.3857       0.2308        1.3858  0.0083
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.5385        1.3857  0.0073
#       2        1.3861       0.3077        1.3853  0.0083
#       3        1.3855       0.3077        1.3850  0.0125
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3865  0.0086
#       2        1.3866       0.2308        1.3863  0.0098
#       3        1.3862       0.2308        1.3861  0.0091
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3857       0.3077        1.3853  0.0070
#       2        1.3852       0.3077        1.3849  0.0087
#       3        1.3847       0.3077        1.3846  0.0096
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3872       0.2308        1.3865  0.0082
#       2        1.3866       0.2308        1.3863  0.0100
#       3        1.3862       0.2308        1.3860  0.0094
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3863  0.0070
#       2        1.3863       0.2308        1.3863  0.0094
#       3        1.3863       0.2308        1.3863  0.0100
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.3846        1.3859  0.0081
#       2        1.3858       0.3077        1.3854  0.0084
#       3        1.3851       0.3077        1.3851  0.0105
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3850  0.0093
#       2        1.3849       0.3077        1.3847  0.0097
#       3        1.3844       0.3077        1.3844  0.0095
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3866  0.0062
#       2        1.3861       0.2308        1.3865  0.0105
#       3        1.3859       0.2308        1.3864  0.0106
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3871       0.2308        1.3865  0.0079
#       2        1.3867       0.2308        1.3862  0.0091
#       3        1.3863       0.2308        1.3860  0.0079
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.2308        1.3855  0.0073
#       2        1.3849       0.2308        1.3849  0.0095
#       3        1.3839       0.5385        1.3845  0.0097
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3878       0.2308        1.3883  0.0086
#       2        1.3871       0.2308        1.3878  0.0102
#       3        1.3866       0.2308        1.3872  0.0107
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3857       0.3077        1.3851  0.0111
#       2        1.3844       0.3077        1.3841  0.0122
#       3        1.3830       0.3077        1.3833  0.0120
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.3077        1.3851  0.0131
#       2        1.3848       0.3077        1.3844  0.0104
#       3        1.3839       0.3077        1.3837  0.0122
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3856  0.0110
#       2        1.3850       0.3077        1.3850  0.0227
#       3        1.3843       0.3077        1.3843  0.0150
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.4615        1.3861  0.0114
#       2        1.3859       0.3077        1.3852  0.0116
#       3        1.3852       0.3077        1.3848  0.0126
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0121
#       2        1.3863       0.2308        1.3863  0.0113
#       3        1.3863       0.2308        1.3863  0.0137
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.3077        1.3856  0.0120
#       2        1.3847       0.3077        1.3846  0.0109
#       3        1.3836       0.3077        1.3838  0.0129
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.3077        1.3856  0.0126
#       2        1.3852       0.3077        1.3850  0.0126
#       3        1.3842       0.3077        1.3844  0.0121
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.3077        1.3854  0.0110
#       2        1.3859       0.3077        1.3847  0.0120
#       3        1.3850       0.3077        1.3844  0.0115
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3861  0.0115
#       2        1.3858       0.2308        1.3860  0.0123
#       3        1.3855       0.2308        1.3854  0.0144
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3862  0.0131
#       2        1.3860       0.2308        1.3860  0.0120
#       3        1.3859       0.2308        1.3857  0.0136
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.2308        1.3859  0.0122
#       2        1.3857       0.2308        1.3857  0.0163
#       3        1.3855       0.2308        1.3853  0.0131
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.2308        1.3858  0.0108
#       2        1.3853       0.3077        1.3844  0.0128
#       3        1.3837       0.3077        1.3830  0.0131
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3853       0.3077        1.3849  0.0129
#       2        1.3845       0.3077        1.3843  0.0142
#       3        1.3836       0.3077        1.3838  0.0139
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.3077        1.3853  0.0116
#       2        1.3851       0.3077        1.3848  0.0158
#       3        1.3842       0.3077        1.3842  0.0130
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3866       0.2308        1.3861  0.0153
#       2        1.3858       0.2308        1.3859  0.0156
#       3        1.3855       0.2308        1.3857  0.0152
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.1538        1.3868  0.0137
#       2        1.3863       0.3846        1.3862  0.0146
#       3        1.3860       0.2308        1.3862  0.0155
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3855  0.0130
#       2        1.3849       0.3846        1.3848  0.0136
#       3        1.3839       0.5385        1.3841  0.0239
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3853  0.0130
#       2        1.3849       0.3077        1.3850  0.0139
#       3        1.3843       0.3077        1.3843  0.0136
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3853  0.0062
#       2        1.3851       0.3077        1.3851  0.0085
#       3        1.3848       0.3077        1.3849  0.0065
#       4        1.3845       0.3077        1.3847  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3858  0.0060
#       2        1.3861       0.3077        1.3856  0.0078
#       3        1.3859       0.3077        1.3854  0.0062
#       4        1.3857       0.3077        1.3852  0.0065
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3875       0.2308        1.3869  0.0060
#       2        1.3870       0.2308        1.3866  0.0068
#       3        1.3866       0.2308        1.3864  0.0066
#       4        1.3862       0.2308        1.3862  0.0068
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3873       0.2308        1.3866  0.0072
#       2        1.3868       0.2308        1.3863  0.0061
#       3        1.3864       0.2308        1.3860  0.0054
#       4        1.3859       0.2308        1.3857  0.0056
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3862  0.0050
#       2        1.3859       0.2308        1.3859  0.0065
#       3        1.3854       0.1538        1.3856  0.0050
#       4        1.3849       0.3077        1.3853  0.0053
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3848       0.3077        1.3847  0.0048
#       2        1.3845       0.3077        1.3844  0.0064
#       3        1.3841       0.3077        1.3842  0.0060
#       4        1.3838       0.3077        1.3839  0.0050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3880       0.2308        1.3874  0.0057
#       2        1.3875       0.2308        1.3871  0.0064
#       3        1.3871       0.4615        1.3868  0.0060
#       4        1.3866       0.2308        1.3866  0.0084
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0060
#       2        1.3863       0.2308        1.3863  0.0069
#       3        1.3863       0.2308        1.3863  0.0054
#       4        1.3863       0.2308        1.3863  0.0080
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3872       0.2308        1.3867  0.0060
#       2        1.3870       0.2308        1.3866  0.0059
#       3        1.3867       0.2308        1.3865  0.0063
#       4        1.3865       0.2308        1.3864  0.0063
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.1538        1.3885  0.0062
#       2        1.3862       0.1538        1.3879  0.0050
#       3        1.3855       0.1538        1.3872  0.0075
#       4        1.3849       0.3846        1.3867  0.0060
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3870       0.2308        1.3870  0.0063
#       2        1.3866       0.2308        1.3868  0.0082
#       3        1.3863       0.2308        1.3866  0.0073
#       4        1.3859       0.2308        1.3864  0.0078
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3872       0.2308        1.3864  0.0071
#       2        1.3867       0.2308        1.3860  0.0094
#       3        1.3861       0.2308        1.3857  0.0084
#       4        1.3856       0.5385        1.3854  0.0071
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3854       0.3077        1.3853  0.0070
#       2        1.3851       0.3077        1.3851  0.0072
#       3        1.3849       0.3077        1.3849  0.0075
#       4        1.3846       0.3077        1.3848  0.0063
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3874       0.2308        1.3873  0.0070
#       2        1.3870       0.2308        1.3870  0.0081
#       3        1.3866       0.2308        1.3867  0.0063
#       4        1.3862       0.2308        1.3864  0.0074
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3885       0.2308        1.3873  0.0110
#       2        1.3882       0.2308        1.3871  0.0125
#       3        1.3878       0.2308        1.3869  0.0089
#       4        1.3875       0.2308        1.3867  0.0070
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3858       0.2308        1.3848  0.0071
#       2        1.3853       0.3077        1.3845  0.0056
#       3        1.3847       0.3077        1.3842  0.0078
#       4        1.3843       0.3077        1.3838  0.0104
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3861  0.0054
#       2        1.3863       0.2308        1.3858  0.0074
#       3        1.3858       0.2308        1.3855  0.0060
#       4        1.3854       0.3077        1.3853  0.0076
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3850       0.3077        1.3847  0.0058
#       2        1.3845       0.3077        1.3844  0.0058
#       3        1.3841       0.3077        1.3842  0.0060
#       4        1.3837       0.3077        1.3839  0.0050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0075
#       2        1.3863       0.2308        1.3863  0.0087
#       3        1.3863       0.2308        1.3863  0.0087
#       4        1.3863       0.2308        1.3863  0.0097
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3864  0.0076
#       2        1.3852       0.3077        1.3857  0.0088
#       3        1.3845       0.3077        1.3849  0.0093
#       4        1.3837       0.3077        1.3842  0.0134
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3858       0.2308        1.3855  0.0085
#       2        1.3851       0.2308        1.3850  0.0104
#       3        1.3843       0.4615        1.3844  0.0099
#       4        1.3835       0.5385        1.3839  0.0069
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0097
#       2        1.3863       0.2308        1.3863  0.0100
#       3        1.3863       0.2308        1.3863  0.0098
#       4        1.3863       0.2308        1.3863  0.0089
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3859  0.0065
#       2        1.3858       0.3077        1.3856  0.0077
#       3        1.3853       0.3077        1.3853  0.0087
#       4        1.3848       0.3077        1.3850  0.0078
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.3077        1.3849  0.0089
#       2        1.3856       0.3077        1.3841  0.0101
#       3        1.3849       0.3077        1.3836  0.0089
#       4        1.3841       0.3077        1.3832  0.0106
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3858       0.3077        1.3854  0.0087
#       2        1.3850       0.3077        1.3850  0.0093
#       3        1.3843       0.3077        1.3844  0.0104
#       4        1.3835       0.3077        1.3839  0.0081
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3871       0.1538        1.3877  0.0210
#       2        1.3865       0.1538        1.3870  0.0112
#       3        1.3860       0.3846        1.3864  0.0105
#       4        1.3854       0.3077        1.3857  0.0095
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3852  0.0074
#       2        1.3852       0.3077        1.3847  0.0103
#       3        1.3844       0.3077        1.3845  0.0145
#       4        1.3840       0.3077        1.3841  0.0091
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2308        1.3863  0.0081
#       2        1.3863       0.2308        1.3863  0.0091
#       3        1.3863       0.2308        1.3863  0.0104
#       4        1.3863       0.2308        1.3863  0.0096
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.2308        1.3860  0.0091
#       2        1.3856       0.4615        1.3854  0.0090
#       3        1.3849       0.4615        1.3848  0.0084
#       4        1.3839       0.3077        1.3842  0.0092
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.3077        1.3859  0.0089
#       2        1.3861       0.3077        1.3855  0.0098
#       3        1.3858       0.3077        1.3852  0.0090
#       4        1.3855       0.3077        1.3849  0.0098
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3869       0.2308        1.3863  0.0094
#       2        1.3864       0.4615        1.3860  0.0098
#       3        1.3859       0.2308        1.3857  0.0093
#       4        1.3853       0.2308        1.3853  0.0097
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3849       0.3077        1.3849  0.0092
#       2        1.3845       0.3077        1.3846  0.0099
#       3        1.3841       0.3077        1.3843  0.0081
#       4        1.3836       0.3077        1.3840  0.0100
# ...
#       8        1.3855       0.2308        1.3862  0.0123
#       9        1.3853       0.2308        1.3862  0.0218
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3852       0.2308        1.3852  0.0115
#       2        1.3850       0.2308        1.3851  0.0172
#       3        1.3849       0.2308        1.3850  0.0118
#       4        1.3846       0.2308        1.3849  0.0128
#       5        1.3844       0.2308        1.3848  0.0115
#       6        1.3843       0.2308        1.3847  0.0096
#       7        1.3841       0.2308        1.3846  0.0131
#       8        1.3839       0.2308        1.3845  0.0110
#       9        1.3837       0.2308        1.3844  0.0134
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.2308        1.3867  0.0331
#       2        1.3860       0.2308        1.3867  0.0153
#       3        1.3858       0.2308        1.3867  0.0118
#       4        1.3858       0.2308        1.3867  0.0080
#       5        1.3858       0.2308        1.3867  0.0089
#       6        1.3857       0.2308        1.3867  0.0108
#       7        1.3856       0.2308        1.3867  0.0102
#       8        1.3856       0.2308        1.3867  0.0104
#       9        1.3855       0.2308        1.3867  0.0114
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3856       0.3077        1.3853  0.0231
#       2        1.3854       0.3077        1.3853  0.0127
#       3        1.3853       0.3077        1.3852  0.0152
#       4        1.3851       0.3077        1.3852  0.0120
#       5        1.3850       0.3077        1.3851  0.0116
#       6        1.3848       0.4615        1.3851  0.0111
#       7        1.3847       0.5385        1.3850  0.0102
#       8        1.3846       0.4615        1.3850  0.0114
#       9        1.3845       0.4615        1.3849  0.0177
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3868  0.0125
#       2        1.3861       0.2308        1.3867  0.0163
#       3        1.3860       0.2308        1.3867  0.0100
#       4        1.3859       0.2308        1.3867  0.0101
#       5        1.3857       0.2308        1.3866  0.0124
#       6        1.3855       0.2308        1.3866  0.0102
#       7        1.3855       0.2308        1.3866  0.0097
#       8        1.3855       0.2308        1.3866  0.0252
#       9        1.3854       0.2308        1.3866  0.0131
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3857       0.2308        1.3864  0.0106
#       2        1.3856       0.2308        1.3864  0.0124
#       3        1.3855       0.2308        1.3864  0.0109
#       4        1.3854       0.2308        1.3864  0.0090
#       5        1.3853       0.2308        1.3864  0.0162
#       6        1.3852       0.2308        1.3864  0.0182
#       7        1.3851       0.2308        1.3864  0.0148
#       8        1.3850       0.2308        1.3864  0.0122
#       9        1.3849       0.2308        1.3863  0.0101
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3857  0.0239
#       2        1.3861       0.3077        1.3856  0.0158
#       3        1.3859       0.3077        1.3855  0.0181
#       4        1.3857       0.3077        1.3854  0.0139
#       5        1.3856       0.3077        1.3853  0.0146
#       6        1.3855       0.3077        1.3852  0.0132
#       7        1.3854       0.3077        1.3852  0.0140
#       8        1.3854       0.3077        1.3851  0.0263
#       9        1.3853       0.3077        1.3850  0.0222
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3867       0.3077        1.3868  0.0186
#       2        1.3865       0.3077        1.3866  0.0142
#       3        1.3863       0.3077        1.3865  0.0129
#       4        1.3860       0.3077        1.3863  0.0144
#       5        1.3859       0.3077        1.3862  0.0123
#       6        1.3857       0.3077        1.3861  0.0100
#       7        1.3855       0.3077        1.3859  0.0114
#       8        1.3854       0.3077        1.3858  0.0143
#       9        1.3851       0.3077        1.3856  0.0119
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3856  0.0352
#       2        1.3859       0.3077        1.3854  0.0243
#       3        1.3856       0.3077        1.3854  0.0157
#       4        1.3854       0.3077        1.3853  0.0183
#       5        1.3852       0.3077        1.3852  0.0146
#       6        1.3851       0.3077        1.3851  0.0163
#       7        1.3848       0.3077        1.3850  0.0186
#       8        1.3845       0.3077        1.3847  0.0167
#       9        1.3842       0.3077        1.3846  0.0145
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.2308        1.3865  0.0158
#       2        1.3857       0.2308        1.3864  0.0271
#       3        1.3855       0.2308        1.3864  0.0145
#       4        1.3853       0.2308        1.3864  0.0154
#       5        1.3851       0.2308        1.3863  0.0144
#       6        1.3849       0.2308        1.3863  0.0140
#       7        1.3847       0.2308        1.3863  0.0267
#       8        1.3846       0.2308        1.3862  0.0153
#       9        1.3843       0.2308        1.3862  0.0138
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3864  0.0159
#       2        1.3862       0.2308        1.3864  0.0144
#       3        1.3860       0.2308        1.3864  0.0135
#       4        1.3859       0.2308        1.3864  0.0144
#       5        1.3858       0.2308        1.3864  0.0135
#       6        1.3856       0.2308        1.3864  0.0132
#       7        1.3854       0.2308        1.3863  0.0201
#       8        1.3853       0.2308        1.3863  0.0181
#       9        1.3851       0.2308        1.3863  0.0143
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.3077        1.3847  0.0125
#       2        1.3861       0.3077        1.3845  0.0131
#       3        1.3859       0.3077        1.3843  0.0140
#       4        1.3857       0.3077        1.3842  0.0134
#       5        1.3856       0.3077        1.3840  0.0139
#       6        1.3854       0.3077        1.3838  0.0129
#       7        1.3852       0.3077        1.3837  0.0242
#       8        1.3851       0.3846        1.3835  0.0148
#       9        1.3849       0.3846        1.3833  0.0160
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3863  0.0138
#       2        1.3860       0.2308        1.3863  0.0121
#       3        1.3859       0.2308        1.3863  0.0151
#       4        1.3858       0.2308        1.3863  0.0153
#       5        1.3856       0.2308        1.3863  0.0152
#       6        1.3854       0.2308        1.3863  0.0184
#       7        1.3853       0.2308        1.3862  0.0156
#       8        1.3851       0.2308        1.3862  0.0252
#       9        1.3850       0.2308        1.3862  0.0219
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.2308        1.3863  0.0347
#       2        1.3856       0.2308        1.3862  0.0241
#       3        1.3855       0.2308        1.3861  0.0130
#       4        1.3852       0.2308        1.3859  0.0165
#       5        1.3850       0.2308        1.3858  0.0205
#       6        1.3848       0.2308        1.3857  0.0321
#       7        1.3845       0.2308        1.3856  0.0201
#       8        1.3842       0.2308        1.3854  0.0202
#       9        1.3840       0.2308        1.3853  0.0152
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.3077        1.3863  0.0151
#       2        1.3863       0.2308        1.3863  0.0185
#       3        1.3863       0.2308        1.3863  0.0174
#       4        1.3863       0.2308        1.3863  0.0262
#       5        1.3863       0.2308        1.3863  0.0216
#       6        1.3863       0.2308        1.3863  0.0183
#       7        1.3863       0.2308        1.3863  0.0363
#       8        1.3863       0.2308        1.3863  0.0215
#       9        1.3863       0.2308        1.3863  0.0157
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3862       0.2308        1.3862  0.0198
#       2        1.3859       0.3077        1.3860  0.0167
#       3        1.3855       0.2308        1.3858  0.0189
#       4        1.3853       0.2308        1.3857  0.0192
#       5        1.3851       0.2308        1.3856  0.0259
#       6        1.3848       0.2308        1.3855  0.0367
#       7        1.3845       0.2308        1.3854  0.0226
#       8        1.3844       0.2308        1.3852  0.0162
#       9        1.3839       0.2308        1.3851  0.0180
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.2308        1.3862  0.0175
#       2        1.3858       0.2308        1.3861  0.0163
#       3        1.3856       0.2308        1.3860  0.0209
#       4        1.3855       0.2308        1.3858  0.0179
#       5        1.3852       0.2308        1.3857  0.0170
#       6        1.3850       0.2308        1.3856  0.0423
#       7        1.3848       0.2308        1.3855  0.0191
#       8        1.3846       0.2308        1.3854  0.0267
#       9        1.3844       0.2308        1.3853  0.0221
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3868       0.3077        1.3861  0.0240
#       2        1.3866       0.3077        1.3858  0.0202
#       3        1.3864       0.3077        1.3855  0.0279
#       4        1.3861       0.3077        1.3853  0.0172
#       5        1.3859       0.3077        1.3850  0.0178
#       6        1.3857       0.3077        1.3847  0.0227
#       7        1.3855       0.3077        1.3844  0.0277
#       8        1.3851       0.3077        1.3842  0.0220
#       9        1.3851       0.3077        1.3841  0.0184
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3855  0.0183
#       2        1.3857       0.3077        1.3853  0.0169
#       3        1.3856       0.3077        1.3852  0.0204
#       4        1.3853       0.3077        1.3851  0.0172
#       5        1.3851       0.3077        1.3849  0.0162
#       6        1.3849       0.3077        1.3848  0.0190
#       7        1.3846       0.3077        1.3846  0.0264
#       8        1.3844       0.3077        1.3845  0.0236
#       9        1.3840       0.3077        1.3843  0.0200
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.2308        1.3863  0.0166
#       2        1.3863       0.2308        1.3863  0.0179
#       3        1.3863       0.2308        1.3863  0.0157
#       4        1.3863       0.2308        1.3863  0.0166
#       5        1.3863       0.2308        1.3863  0.0180
#       6        1.3863       0.2308        1.3863  0.0208
#       7        1.3863       0.2308        1.3863  0.0175
#       8        1.3863       0.2308        1.3863  0.0310
#       9        1.3863       0.2308        1.3863  0.0206
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3860  0.0179
#       2        1.3860       0.3077        1.3858  0.0207
#       3        1.3857       0.3077        1.3857  0.0210
#       4        1.3854       0.3077        1.3857  0.0211
#       5        1.3853       0.3077        1.3855  0.0178
#       6        1.3851       0.3077        1.3854  0.0205
#       7        1.3849       0.3077        1.3853  0.0177
#       8        1.3847       0.3077        1.3851  0.0272
#       9        1.3845       0.3077        1.3850  0.0274
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3863       0.3077        1.3858  0.0164
#       2        1.3862       0.3077        1.3856  0.0164
#       3        1.3861       0.3077        1.3855  0.0232
#       4        1.3860       0.3077        1.3854  0.0241
#       5        1.3859       0.3077        1.3853  0.0420
#       6        1.3858       0.3077        1.3852  0.0318
#       7        1.3857       0.3077        1.3851  0.0201
#       8        1.3856       0.3077        1.3850  0.0204
#       9        1.3855       0.3077        1.3849  0.0244
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3859       0.3077        1.3853  0.0227
#       2        1.3858       0.3077        1.3852  0.0379
#       3        1.3857       0.3077        1.3851  0.0561
#       4        1.3856       0.3077        1.3849  0.0221
#       5        1.3855       0.3077        1.3848  0.0215
#       6        1.3853       0.3077        1.3847  0.0204
#       7        1.3852       0.3077        1.3846  0.0184
#       8        1.3851       0.3077        1.3845  0.0200
#       9        1.3850       0.3077        1.3844  0.0193
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3860       0.3077        1.3861  0.0206
#       2        1.3857       0.2308        1.3859  0.0162
#       3        1.3854       0.2308        1.3857  0.0513
#       4        1.3852       0.2308        1.3855  0.0359
#       5        1.3851       0.2308        1.3855  0.0285
#       6        1.3849       0.2308        1.3854  0.0200
#       7        1.3847       0.2308        1.3853  0.0195
#       8        1.3845       0.2308        1.3853  0.0192
#       9        1.3844       0.2308        1.3852  0.0392
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.2308        1.3868  0.0188
#       2        1.3861       0.2308        1.3868  0.0203
#       3        1.3858       0.2308        1.3867  0.0177
#       4        1.3854       0.2308        1.3866  0.0171
#       5        1.3851       0.2308        1.3865  0.0288
#       6        1.3849       0.2308        1.3865  0.0254
#       7        1.3846       0.2308        1.3866  0.0248
#       8        1.3845       0.2308        1.3866  0.0191
#       9        1.3844       0.2308        1.3865  0.0172
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3865       0.3077        1.3862  0.0184
#       2        1.3862       0.3077        1.3859  0.0239
#       3        1.3860       0.3077        1.3858  0.0202
#       4        1.3859       0.3077        1.3857  0.0201
#       5        1.3859       0.3077        1.3857  0.0271
#       6        1.3857       0.3077        1.3856  0.0279
#       7        1.3855       0.3077        1.3856  0.0256
#       8        1.3854       0.3077        1.3855  0.0216
#       9        1.3853       0.3077        1.3855  0.0173
# SEARCH COMPLETE
# best score: 0.523, best params: {'lr': 0.002, 'max_epochs': 8, 'module__hidden_size': 64, 'optimizer': <class 'torch.optim.adamax.Adamax'>, 'optimizer__eps': 1e-08}

# %%
# Suppose you have logits for three classes
m = torch.nn.Softmax(dim=1)

logits = torch.rand((128, 4))
print(logits.size())

print(m(logits).size())

# Using view(-1) to flatten the logits tensor

print(logits.size())
print(logits.view(-1, 4).size())
# Out:
# torch.Size([128, 4])
# torch.Size([128, 4])
# torch.Size([128, 4])
# torch.Size([128, 4])

# %%
random_tensor = torch.rand(128)
labels_tensor = 3 * random_tensor + 1
print(label_batch)
# Out:
# tensor([3, 0, 1, 3, 3, 0, 0, 3, 3, 3, 2, 1, 2, 3, 0, 1, 1, 0, 1, 2, 2, 1, 3, 2,
#         2, 1, 1, 2, 0, 3, 2, 0, 3, 1, 0, 3, 1, 1, 2, 3, 3, 1, 0, 0, 0, 0, 2, 1,
#         2, 0, 1, 3, 2, 2, 1, 3, 3, 1, 3, 3, 3, 3, 0, 3, 1, 1, 0, 0, 2, 1, 1, 3,
#         2, 0, 3, 0, 0, 1, 1, 1, 2, 1, 0, 1, 0, 3, 0, 2, 0, 2, 1, 3, 0, 0, 3, 1,
#         0, 0, 2, 1, 1, 2, 3, 3, 1, 2, 3, 2, 0, 3, 0, 2, 2, 3, 0, 0, 1, 3, 0, 1,
#         1, 0, 0, 1, 3, 0, 1, 3])

# %%
loss_fct = CrossEntropyLoss()
loss = loss_fct(logits.view(-1, 4), label_batch.view(-1))
loss
# Out:
# tensor(1.4468)

# %%
from ignite.metrics import ClassificationReport

metric = ClassificationReport(output_dict=True)
metric.attach(default_evaluator, "cr")

state = default_evaluator.run([[logits, label_batch]])
print(state.metrics["cr"].keys())
print(state.metrics["cr"]["0"])
print(state.metrics["cr"]["1"])
print(state.metrics["cr"]["2"])
print(state.metrics["cr"]["macro avg"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <module>
#       1 from ignite.metrics import ClassificationReport
#       3 metric = ClassificationReport(output_dict=True)
# ----> 4 metric.attach(default_evaluator, "cr")
#       6 state = default_evaluator.run([[logits, label_batch]])
#       7 print(state.metrics["cr"].keys())
#
# NameError: name 'default_evaluator' is not defined
